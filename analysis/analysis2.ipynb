# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
print(plt.style.available)
plt.style.use('ggplot')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
pd.set_option('display.max_columns', None)

# %%
data_science = pd.read_excel('data_science.xlsx', skiprows='3700' )

# %%
data_science
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
# ...

# %%
data_science.head()
# Out:
#    work_year experience_level employment_type                job_title  \
# 0       2023               EN              FT        Applied Scientist
# 1       2023               EN              FT        Applied Scientist
# 2       2023               EN              FT     Data Quality Analyst
# 3       2023               EN              FT  Compliance Data Analyst
# 4       2023               EN              FT        Applied Scientist
#
#    salary salary_currency  salary_in_usd company_location company_size
# 0  213660             USD         213660               US            L
# 1  130760             USD         130760               US            L
# 2  100000             USD         100000               NG            L
# 3   30000             USD          30000               NG            L
# 4  204620             USD         204620               US            L

# %%
data_science.tail()
# Out:
#       work_year experience_level employment_type                  job_title  \
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
#       salary salary_currency  salary_in_usd company_location company_size
# 3756  130000             EUR         148261               DE            M
# 3757   80000             EUR          91237               AT            S
# 3758  190200             USD         190200               US            M
# 3759   40000             EUR          45618               HR            S
# 3760  412000             USD         412000               US            L

# %%
data_science.sample(5)
# Out:
#       work_year experience_level employment_type                job_title  \
# 3702       2020               EN              FT  Data Science Consultant
# 1675       2023               SE              FT            Data Engineer
# 3027       2022               SE              FT            Data Engineer
# 3633       2021               SE              FT   Marketing Data Analyst
# 1947       2022               EX              FT     Head of Data Science
#
#       salary salary_currency  salary_in_usd company_location company_size
# 3702  423000             INR           5707               IN            M
# 1675  133800             USD         133800               US            M
# 3027  160000             USD         160000               US            M
# 3633   75000             EUR          88654               DK            L
# 1947  224000             USD         224000               US            M

# %%
data_science['job_title']
# Out:
# 0               Applied Scientist
# 1               Applied Scientist
# 2            Data Quality Analyst
# 3         Compliance Data Analyst
# 4               Applied Scientist
#                   ...
# 3756     Principal Data Scientist
# 3757               Data Scientist
# 3758         Data Science Manager
# 3759    Machine Learning Engineer
# 3760               Data Scientist
# Name: job_title, Length: 3761, dtype: object

# %%
data_science.salary
# Out:
# 0       213660
# 1       130760
# 2       100000
# 3        30000
# 4       204620
#          ...
# 3756    130000
# 3757     80000
# 3758    190200
# 3759     40000
# 3760    412000
# Name: salary, Length: 3761, dtype: int64

# %%
data_science.salary_currency
# Out:
# 0       USD
# 1       USD
# 2       USD
# 3       USD
# 4       USD
#        ...
# 3756    EUR
# 3757    EUR
# 3758    USD
# 3759    EUR
# 3760    USD
# Name: salary_currency, Length: 3761, dtype: object

# %%
cols = ['job_title', 'salary'  , 'experience_level', 'employment_type', 'work_year']
data_science[cols]
# Out:
#                       job_title  salary experience_level employment_type  \
# 0             Applied Scientist  213660               EN              FT
# 1             Applied Scientist  130760               EN              FT
# 2          Data Quality Analyst  100000               EN              FT
# 3       Compliance Data Analyst   30000               EN              FT
# 4             Applied Scientist  204620               EN              FT
# ...                         ...     ...              ...             ...
# 3756   Principal Data Scientist  130000               SE              FT
# 3757             Data Scientist   80000               SE              FT
# 3758       Data Science Manager  190200               SE              FT
# 3759  Machine Learning Engineer   40000               SE              FT
# 3760             Data Scientist  412000               SE              FT
#
#       work_year
# 0          2023
# 1          2023
# 2          2023
# 3          2023
# ...

# %%
data_science.iloc[3]
# Out:
# work_year                              2023
# experience_level                         EN
# employment_type                          FT
# job_title           Compliance Data Analyst
# salary                                30000
# salary_currency                         USD
# salary_in_usd                         30000
# company_location                         NG
# company_size                              L
# Name: 3, dtype: object

# %%
data_science.iloc[3,3 ]
# Out:
# 'Compliance Data Analyst'

# %%
 data_science.iloc[3, 3:]
# Out:
# job_title           Compliance Data Analyst
# salary                                30000
# salary_currency                         USD
# salary_in_usd                         30000
# company_location                         NG
# company_size                              L
# Name: 3, dtype: object

# %%
x = ['job_title', 'salary']
data_science[x].plot(kind='bar', x ='job_title')
# Out:
# <Axes: xlabel='job_title'>
